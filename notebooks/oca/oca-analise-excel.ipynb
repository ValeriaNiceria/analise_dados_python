# %% [markdown]
# # Análise de Dados de Filmes Exibidos no Brasil de 2009 a 2017
# > Com base nos dados da Ancine (https://oca.ancine.gov.br/)

# %%
# Importando a biblioteca pandas
import pandas as pd
# Informando para o pandas mostrar o gráfico no jupyter notebook
# %matplotlib inline

# %%
# Lendo o arquivo e atribuindo a uma variável - convertendo o arquivo em um DataFrame
# Pulando as 2 primeiras linhas (skiprows)
# Descartando as últimas 16 linhas (skipfooter)
df = pd.read_excel('ListagemFilmesBrasileirosEstrangeirosExibidos2009-2017.xlsx', skiprows=2, skipfooter=16)

# %%
# Exibindo as 5 primeiras linhas do DataFrame
df.head()
# Out:
#    Ano de exibição                      Título da obra        Gênero  \
# 0             2017                          #Screamers        Ficção
# 1             2017  10 Centavos para o Número da Besta  Documentário
# 2             2017           120 batimentos por minuto        Ficção
# 3             2017                          13 Minutos        Ficção
# 4             2017                      150 Miligramas        Ficção
#
#   País(es) produtor(es) da obra Nacionalidade da obra   Data de lançamento  \
# 0                Estados Unidos          Estrangeiros  2017-11-30 00:00:00
# 1                        Brasil           Brasileiros  2017-11-28 00:00:00
# 2                        França          Estrangeiros  2018-01-04 00:00:00
# 3                      Alemanha          Estrangeiros  2016-11-03 00:00:00
# 4                        França          Estrangeiros  2017-08-31 00:00:00
#
#          Distribuidora Origem da empresa distribuidora  \
# 0       Cineart Filmes           Distribuição Nacional
# 1  Ponto de Equilíbrio           Distribuição Nacional
# 2           Imovision            Distribuição Nacional
# 3    Alphaville Filmes           Distribuição Nacional
# 4          Califórnia            Distribuição Nacional
#
#    Público no ano de exibição  Renda (R$) no ano de exibição
# 0                         714                        9437.45
# 1                           7                          63.00
# 2                         262                        3791.63
# 3                         620                        6463.50
# 4                         771                       10508.71

# %%
# Exibindo as 5 últimas linhas do DataFrame
df.tail(5)
# Out:
#       Ano de exibição                   Título da obra        Gênero  \
# 5686             2009         X-Men Origens: Wolverine        Ficção
# 5687             2009  Xuxa em o Mistério de Feiurinha        Ficção
# 5688             2009          Xuxa em Sonho de Menina        Ficção
# 5689             2009                      Xuxa Gêmeas        Ficção
# 5690             2009                     Zico na Rede  Documentário
#
#      País(es) produtor(es) da obra Nacionalidade da obra   Data de lançamento  \
# 5686                Estados Unidos          Estrangeiros  2009-05-01 00:00:00
# 5687                        Brasil           Brasileiros  2009-12-25 00:00:00
# 5688                        Brasil           Brasileiros  2007-12-21 00:00:00
# 5689                        Brasil           Brasileiros  2006-12-15 00:00:00
# 5690                        Brasil           Brasileiros  2009-07-03 00:00:00
#
#          Distribuidora Origem da empresa distribuidora  \
# 5686               Fox      Distribuição Internacional
# 5687          Playarte           Distribuição Nacional
# 5688            Warner      Distribuição Internacional
# 5689               Fox      Distribuição Internacional
# 5690  Business Telecom           Distribuição Nacional
#
#       Público no ano de exibição  Renda (R$) no ano de exibição
# 5686                     3199434                    27352313.00
# 5687                      250109                     1766416.65
# 5688                        8914                       26880.00
# 5689                        1671                        5013.00
# 5690                         546                        2529.50

# %%
# Verificar todos os tipos das colunas
df.dtypes
# Out:
# Ano de exibição                      int64
# Título da obra                      object
# Gênero                              object
# País(es) produtor(es) da obra       object
# Nacionalidade da obra               object
# Data de lançamento                  object
# Distribuidora                       object
# Origem da empresa distribuidora     object
# Público no ano de exibição           int64
# Renda (R$) no ano de exibição      float64
# dtype: object

# %%
# Convertendo o campo 'Data de lançamento' em data
df['Data de lançamento'] = pd.to_datetime(df['Data de lançamento'])
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/tslibs/np_datetime.pyx in pandas._libs.tslibs.np_datetime._string_to_dts()
#
# UnicodeEncodeError: 'ascii' codec can't encode character '\xe7' in position 5: ordinal not in range(128)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/tslibs/parsing.pyx in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# ~/anaconda3/lib/python3.7/site-packages/dateutil/parser/_parser.py in parse(timestr, parserinfo, **kwargs)
#    1355     else:
# -> 1356         return DEFAULTPARSER.parse(timestr, **kwargs)
#    1357
#
# ~/anaconda3/lib/python3.7/site-packages/dateutil/parser/_parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     647         if res is None:
# --> 648             raise ValueError("Unknown string format:", timestr)
#     649
#
# ValueError: ('Unknown string format:', 'Relançamento')
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-b072ac130db4> in <module>
#       1 # Convertendo o campo 'Data de lançamento' em data
# ----> 2 df['Data de lançamento'] = pd.to_datetime(df['Data de lançamento'])
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, box, format, exact, unit, infer_datetime_format, origin, cache)
#     449         else:
#     450             from pandas import Series
# --> 451             values = _convert_listlike(arg._values, True, format)
#     452             result = Series(values, index=arg.index, name=arg.name)
#     453     elif isinstance(arg, (ABCDataFrame, MutableMapping)):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/tools/datetimes.py in _convert_listlike(arg, box, format, name, tz)
#     366                     dayfirst=dayfirst,
#     367                     yearfirst=yearfirst,
# --> 368                     require_iso8601=require_iso8601
#     369                 )
#     370
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# TypeError: invalid string coercion to datetime

# %%
# Tentando identificar o problema da coluna 'Data de lançamento'
df['Data de lançamento'].value_counts()
# Out:
# Relançamento           175
# 2012-12-21 00:00:00     33
# 2015-12-03 00:00:00     33
# 2013-11-29 00:00:00     29
# 2012-11-02 00:00:00     27
# 2015-11-19 00:00:00     25
# 2015-11-12 00:00:00     25
# 2013-10-11 00:00:00     23
# 2013-11-01 00:00:00     23
# 2013-12-06 00:00:00     23
# 2016-11-17 00:00:00     23
# 2013-09-13 00:00:00     21
# 2014-11-06 00:00:00     21
# 2011-11-11 00:00:00     21
# 2011-12-02 00:00:00     21
# 2009-12-11 00:00:00     20
# 2011-09-30 00:00:00     19
# 2016-11-10 00:00:00     19
# 2014-06-19 00:00:00     19
# 2013-12-20 00:00:00     19
# 2011-12-09 00:00:00     19
# 2016-11-24 00:00:00     18
# 2015-08-20 00:00:00     18
# 2011-11-25 00:00:00     18
# 2015-11-26 00:00:00     18
# 2015-12-10 00:00:00     18
# 2013-09-06 00:00:00     18
# 2016-12-01 00:00:00     18
# 2012-10-12 00:00:00     18
# 2014-12-04 00:00:00     18
#                       ...
# 2004-01-09 00:00:00      1
# 2005-10-07 00:00:00      1
# 2008-11-29 00:00:00      1
# 2002-11-01 00:00:00      1
# 2009-03-07 00:00:00      1
# 2007-09-21 00:00:00      1
# 2013-03-23 00:00:00      1
# 2010-05-30 00:00:00      1
# 2009-05-23 00:00:00      1
# 2011-10-01 00:00:00      1
# 2010-02-06 00:00:00      1
# 2008-05-02 00:00:00      1
# 2009-06-23 00:00:00      1
# 2018-01-25 00:00:00      1
# 2018-03-01 00:00:00      1
# 2010-06-22 00:00:00      1
# 2010-06-30 00:00:00      1
# 2008-04-12 00:00:00      1
# 2005-02-04 00:00:00      1
# 2007-06-30 00:00:00      1
# 2006-08-18 00:00:00      1
# 2011-03-19 00:00:00      1
# 2015-11-01 00:00:00      1
# 2005-07-29 00:00:00      1
# 2013-09-30 00:00:00      1
# 2007-12-07 00:00:00      1
# 2017-03-29 00:00:00      1
# 2013-11-05 00:00:00      1
# 2012-06-09 00:00:00      1
# 2008-01-12 00:00:00      1
# Name: Data de lançamento, Length: 759, dtype: int64

# %%
# Exibir filmes que campo 'Data de lançamento' igual à Relançamento
df[df['Data de lançamento'] == 'Relançamento']
# Out:
#       Ano de exibição                             Título da obra  \
# 7                2017                                         8½
# 11               2017                            A bela da tarde
# 36               2017                         A História sem Fim
# 53               2017               A primeira noite de um homem
# 128              2017          Ballet Bolshoi: A bela adormecida
# 130              2017  Ballet Bolshoi: Um herói de nossos tempos
# 131              2017     Ballet Bolshoi: Uma noite conteporânea
# 144              2017             Blow-Up - Depois Daquele Beijo
# 272              2017                       Estranhos no Paraíso
# 291              2017                               Fitzcarraldo
# 305              2017                         Gritos e Sussurros
# 311              2017                         Hiroshima Meu Amor
# 384              2017                                 Mamma Roma
# 414              2017                        Morangos Silvestres
# 422              2017       Mulholland Drive - Cidade dos Sonhos
# 448              2017             Nosferatu - O Vampiro da Noite
# 473              2017                       O Fantasma do Futuro
# 484              2017                  O homem que caiu na Terra
# 514              2017                              O Sétimo Selo
# 552              2017                            Patrulha Canina
# 554              2017                 Pearl Jam - Let’s Play Two
# 586              2017                           Rammstein: Paris
# 617              2017                Slipknot: Day of the Gusano
# 632              2017                                Taxi Driver
# 643              2017                                 Titanic 3D
# 709              2016               2001: Uma Odisséia no Espaço
# 712              2016                                         8½
# 718              2016                         A Bela e a Fera 3D
# 729              2016                       A Dama e o Vagabundo
# 731              2016                                A doce vida
# ...               ...                                        ...
# 2865             2014                            Touro Indomável
# 2886             2014                           Um Corpo que Cai
# 2902             2014                           Uma Linda Mulher
# 2953             2013                         A Bela e a Fera 3D
# 3070             2013                  Cabra Marcado para Morrer
# 3222             2013                           Jurassic Park 3D
# 3228             2013                           Laranja mecânica
# 3263             2013                               Monstros S.A
# 3332             2013                              O Rei Leão 3D
# 3476             2013                           Um Corpo que Cai
# 3502             2013                         Violência e Paixão
# 3532             2012                         A Bela e a Fera 3D
# 3652             2012                  Cabra Marcado para Morrer
# 3874             2012                              O Rei Leão 3D
# 3925             2012                            Procurando Nemo
# 3936             2012                  Quanto Mais Quente Melhor
# 3976             2012  Star Wars: Episódio I – A ameaça fantasma
# 3984             2012                                 Titanic 3D
# 4264             2011                              Ginger e Fred
# 4413             2011                              O Rei Leão 3D
# 4433             2011                    Os Contos de Canterbury
# 4581             2011                         Violência e Paixão
# 4953             2010                    Os Contos de Canterbury
# 5051             2010                                Toy story 2
# 5053             2010                               Toy story 3D
# 5113             2009                                   A agenda
# 5351             2009                              Fome de Viver
# 5529             2009                    Os Contos de Canterbury
# 5577             2009                                Ratatouille
# 5609             2009                                  Sofá Cama
#
#             Gênero        País(es) produtor(es) da obra Nacionalidade da obra  \
# 7           Ficção                       França, Itália          Estrangeiros
# 11          Ficção                       França, Itália          Estrangeiros
# 36          Ficção             Alemanha, Estados Unidos          Estrangeiros
# 53          Ficção                       Estados Unidos          Estrangeiros
# 128   Vídeomusical                           Inglaterra          Estrangeiros
# 130   Vídeomusical                           Inglaterra          Estrangeiros
# 131   Vídeomusical                           Inglaterra          Estrangeiros
# 144         Ficção  Estados Unidos, Itália, Reino Unido          Estrangeiros
# 272         Ficção             Alemanha, Estados Unidos          Estrangeiros
# 291         Ficção                       Alemanha, Peru          Estrangeiros
# 3936           Distribuição Nacional                        2010
# 3976      Distribuição Internacional                      163776
# 3984      Distribuição Internacional                      679103
# 4264           Distribuição Nacional                         106
# 4413      Distribuição Internacional                      304367
# 4433           Distribuição Nacional                         106
# 4581           Distribuição Nacional                        3079
# 4953           Distribuição Nacional                          54
# 5051      Distribuição Internacional                      162034
# 5053      Distribuição Internacional                       96973
# 5113           Distribuição Nacional                          33
# 5351           Distribuição Nacional                         268
# 5529           Distribuição Nacional                        5026
# 5577      Distribuição Internacional                         230
# 5609           Distribuição Nacional                         579
#
#       Renda (R$) no ano de exibição
# 7                            196.00
# 11                         42839.31
# 36                          6969.00
# 53                            96.00
# 128                        41391.00
# 130                        14744.00
# 131                        19025.00
# 144                        29871.00
# 272                         2844.70
# 291                          112.00
# 305                        10982.50
# 311                        73603.42
# 384                          206.50
# 414                         4561.00
# 422                        60615.03
# 448                          434.00
# 473                        73990.99
# 484                        51322.00
# 514                         5998.00
# 552                       172693.42
# 554                        61112.50
# 586                        25508.00
# 617                        15619.70
# 632                        13636.00
# 643                        69406.00
# 709                        15108.00
# 712                        42990.41
# 718                        84967.00
# 729                        18843.00
# 731                          900.00
# ...                             ...
# 2865                       15769.50
# 2886                       89430.03
# 2902                       34956.00
# 2953                         561.00
# 3070                        3361.27
# 3222                      180186.00
# 3228                       35314.50
# 3263                     1163316.00
# 3332                        1105.00
# 3476                       39931.34
# 3502                         463.00
# 3532                     1940654.00
# 3652                        6041.50
# 3874                       23545.00
# 3925                     2079682.00
# 3936                       20279.50
# 3976                     2362210.74
# 3984                     9746413.99
# 4264                         217.00
# 4413                     4069169.50
# 4433                         893.00
# 4581                       23310.50
# 4953                         260.00
# 5051                     2225107.75
# 5053                     1308293.25
# 5113                         154.50
# 5351                         944.00
# 5529                       29614.00
# 5577                        2300.00
# 5609                        3529.60
#
# [175 rows x 10 columns]

# %% [markdown]
# ## Decisão sobre dados incorretos/faltantes/divergentes

# %%
# Tamanho do DataFrame
df.shape
# Out:
# (5691, 10)

# %%
# Criando um novo DataFrame sem o campo 'Data de lançamento' igual à Relançamento
df_novo = df[df['Data de lançamento'] != 'Relançamento']

# %%
df_novo[df_novo['Data de lançamento'] == 'Relançamento']
# Out:
# Empty DataFrame
# Columns: [Ano de exibição, Título da obra, Gênero, País(es) produtor(es) da obra, Nacionalidade da obra, Data de lançamento, Distribuidora, Origem da empresa distribuidora, Público no ano de exibição, Renda (R$) no ano de exibição]
# Index: []

# %%
# Tamanho do novo DataFrame
df_novo.shape
# Out:
# (5516, 10)

# %%
# Convertendo a coluna 'Data de lançamento' para datetime
df_novo['Data de lançamento'] = pd.to_datetime(df_novo['Data de lançamento'])
# Out:
# /home/valeria/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# Verificando os tipos das colunas
df_novo.dtypes
# Out:
# Ano de exibição                             int64
# Título da obra                             object
# Gênero                                     object
# País(es) produtor(es) da obra              object
# Nacionalidade da obra                      object
# Data de lançamento                 datetime64[ns]
# Distribuidora                              object
# Origem da empresa distribuidora            object
# Público no ano de exibição                  int64
# Renda (R$) no ano de exibição             float64
# dtype: object

# %%
# Quais os anos tiveram mais filmes lançados
num_filmes_ano = df_novo['Data de lançamento'].dt.year.value_counts()

# %%
# Plotando no gráfico 
num_filmes_ano.plot.bar()
